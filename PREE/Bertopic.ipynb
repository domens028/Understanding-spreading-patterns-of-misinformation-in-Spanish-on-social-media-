# %%
import pandas as pd
import numpy as np
import json
from pandas import json_normalize
import plotly.express as px
from urllib.parse import urlparse
from langdetect import detect
from datetime import date
from datetime import timedelta

# %%
from bertopic import BERTopic
#Eliminamos los valores cn java script y los na 
df = pd.read_csv('data_bertopic3.csv')
pr = df.loc[(df['languague'] == 'es')]
pr.reset_index(inplace=True, drop=True)
docs = pr['text']
print(docs.count())
# Out:
# 10168

# %%
from bertopic.vectorizers import ClassTfidfTransformer
from sklearn.feature_extraction.text import CountVectorizer


ctfidf_model = ClassTfidfTransformer(reduce_frequent_words=True)

topic_model = BERTopic(ctfidf_model=ctfidf_model, nr_topics=100 ,calculate_probabilities=True, verbose=True)
topics, probs = topic_model.fit_transform(docs)
# Out:
# Batches:   0%|          | 0/318 [00:00<?, ?it/s]
# 2023-05-01 17:30:49,674 - BERTopic - Transformed documents to Embeddings
# 2023-05-01 17:30:58,878 - BERTopic - Reduced dimensionality
# 2023-05-01 17:31:39,452 - BERTopic - Clustered reduced embeddings
# 2023-05-01 17:32:16,090 - BERTopic - Reduced number of topics from 194 to 101

# %%
topic_model.get_topic_info()
# Out:
#      Topic  Count                                     Name
# 0       -1   4351                        -1_sin_son_han_ya
# 1        0    645                0_diestro_tv_carrey_pachi
# 2        1    246                1_gnero_sexo_trans_sexual
# 3        2    202                    2_china_pcch_chino_xi
# 4        3    190         3_pfizer_vacunas_covid_vacunacin
# ..     ...    ...                                      ...
# 96      95     21      95_et_myocarditis_vaccination_after
# 97      96     21  96_trump_republicanos_demcratas_arizona
# 98      97     21                    97_jos_san_done_ruega
# 99      98     21          98_saturno_color_cubo_gelatinas
# 100     99     21            99_arnm_lnp_exosomas_vesculas
#
# [101 rows x 3 columns]

# %%
output = topic_model.get_topic_info()
output.to_csv('bertopicResults.csv')

# %%
from sklearn.datasets import fetch_20newsgroups
from sentence_transformers import SentenceTransformer
from bertopic import BERTopic
from umap import UMAP

embeddings = sentence_model.encode(docs, show_progress_bar=False)

# Train BERTopic
topic_model = BERTopic().fit(docs, embeddings)

# Run the visualization with the original embeddings
topic_model.visualize_documents(docs, embeddings=embeddings)

# Reduce dimensionality of embeddings, this step is optional but much faster to perform iteratively:
reduced_embeddings = UMAP(n_neighbors=10, n_components=2, min_dist=0.0, metric='cosine').fit_transform(embeddings)
topic_model.visualize_documents(docs, reduced_embeddings=reduced_embeddings)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\domin\Documents\GitHub\TFG-DOMINGO-MENENDEZ-RUA\TFG-DOMINGO-MENENDEZ-RUA\TFG-DOMINGO-MENENDEZ-RUA\TFG-DOMINGO-MENENDEZ-RUA\TEST\Bertopic.ipynb Cell 6 in 5
#       <a href='vscode-notebook-cell:/c%3A/Users/domin/Documents/GitHub/TFG-DOMINGO-MENENDEZ-RUA/TFG-DOMINGO-MENENDEZ-RUA/TFG-DOMINGO-MENENDEZ-RUA/TFG-DOMINGO-MENENDEZ-RUA/TEST/Bertopic.ipynb#X15sZmlsZQ%3D%3D?line=2'>3</a> from bertopic import BERTopic
#       <a href='vscode-notebook-cell:/c%3A/Users/domin/Documents/GitHub/TFG-DOMINGO-MENENDEZ-RUA/TFG-DOMINGO-MENENDEZ-RUA/TFG-DOMINGO-MENENDEZ-RUA/TFG-DOMINGO-MENENDEZ-RUA/TEST/Bertopic.ipynb#X15sZmlsZQ%3D%3D?line=3'>4</a> from umap import UMAP
# ...

# %%
topic_model.visualize_topics()

# %%
df = topic_model.get_topic_info()
df.to_csv('bertopicResults.csv')

# %%
# Calculate the topic distributions on a token-level
topic_distr, topic_token_distr = topic_model.approximate_distribution(docs, calculate_tokens=True)

# Visualize the token-level distributions
df = topic_model.visualize_approximate_distribution(docs, topic_token_distr)
df
# Out:
# 100%|██████████| 11/11 [02:23<00:00, 13.01s/it]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\domin\Documents\GitHub\TFG-DOMINGO-MENENDEZ-RUA\TFG-DOMINGO-MENENDEZ-RUA\TFG-DOMINGO-MENENDEZ-RUA\TFG-DOMINGO-MENENDEZ-RUA\TEST\Bertopic.ipynb Cell 12 in 5
#       <a href='vscode-notebook-cell:/c%3A/Users/domin/Documents/GitHub/TFG-DOMINGO-MENENDEZ-RUA/TFG-DOMINGO-MENENDEZ-RUA/TFG-DOMINGO-MENENDEZ-RUA/TFG-DOMINGO-MENENDEZ-RUA/TEST/Bertopic.ipynb#X12sZmlsZQ%3D%3D?line=1'>2</a> topic_distr, topic_token_distr = topic_model.approximate_distribution(docs, calculate_tokens=True)
#       <a href='vscode-notebook-cell:/c%3A/Users/domin/Documents/GitHub/TFG-DOMINGO-MENENDEZ-RUA/TFG-DOMINGO-MENENDEZ-RUA/TFG-DOMINGO-MENENDEZ-RUA/TFG-DOMINGO-MENENDEZ-RUA/TEST/Bertopic.ipynb#X12sZmlsZQ%3D%3D?line=3'>4</a> # Visualize the token-level distributions
# ...
